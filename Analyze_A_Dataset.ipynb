# %% [markdown]
# ## Julien Wilson | February 4, 2017

# %% [markdown]
# This Dataset describes housing information for neighborhoods accross boston.  According to the source website at UCI: https://archive.ics.uci.edu/ml/datasets/Housing, the data attributes are as follows:
#
#     1. CRIM: per capita crime rate by town
#     2. ZN: proportion of residential land zoned for lots over 25,000 sq.ft.
#     3. INDUS: proportion of non-retail business acres per town
#     4. CHAS: Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#     5. NOX: nitric oxides concentration (parts per 10 million)
#     6. RM: average number of rooms per dwelling
#     7. AGE: proportion of owner-occupied units built prior to 1940
#     8. DIS: weighted distances to five Boston employment centres
#     9. RAD: index of accessibility to radial highways
#     10. TAX: full-value property-tax rate per $10,000
# 11. PTRATIO: pupil-teacher ratio by town
# 12. B: 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
# 13. LSTAT: % lower status of the population
# 14. MEDV: Median value of owner-occupied homes in $1000's

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
housing = pd.read_csv("boston_housing_data.csv", sep=" ", names = ["nothing", "CRIM", "ZN", "INDUS", "CHAS", "NOX", "RM", "AGE", "DIS", "RAD", "TAX", "PTRATIO", "B", "LSTAT", "MEDV"])

# %%
del housing['nothing']

# %%
housing
# Out:
#         CRIM    ZN  INDUS   CHAS    NOX      RM       AGE      DIS    RAD  \
# 0    0.00632  18.0   2.31  0.000  0.538   6.575   65.2000   4.0900    1.0
# 1    0.02731   0.0   7.07  0.000  0.469   6.421   78.9000   4.9671    2.0
# 2    0.02729   0.0   7.07  0.000  0.469   7.185   61.1000   4.9671    2.0
# 3    0.03237   0.0   2.18  0.000  0.458   6.998   45.8000   6.0622    3.0
# 4    0.06905   0.0   2.18  0.000  0.458   7.147   54.2000   6.0622    3.0
# 5    0.02985   0.0   2.18  0.000  0.458   6.430   58.7000   6.0622    3.0
# 6    0.08829  12.5   7.87  0.000  0.524   6.012   66.6000   5.5605    5.0
# 7    0.14455  12.5   7.87  0.000  0.524   6.172   96.1000   5.9505    5.0
# 8    0.21124  12.5   7.87  0.000  0.524   5.631  100.0000   6.0821    5.0
# 9    0.17004  12.5   7.87  0.000  0.524   6.004   85.9000   6.5921    5.0
# 10   0.22489  12.5   7.87  0.000  0.524   6.377   94.3000   6.3467    5.0
# 11   0.11747  12.5   7.87  0.000  0.524   6.009   82.9000   6.2267    5.0
# ...

# %% [markdown]
# Some descriptive statistics about the housing prices.  These represent values derived from the median values for neigborhoods.  So the mean is not the average house price in Boston, it is the average of the median value for every neighborhood.

# %%
mean_price = housing['MEDV'].mean()

# %%
mean_price * 1000
# Out:
# 23750.442477876106

# %%
median_price = housing['MEDV'].median()

# %%
median_price * 1000
# Out:
# 21950.0

# %% [markdown]
# Finding the median housing price for the neighborhood with the 'newest' houses (smallest proportion built before 1940)

# %%
housing[housing.AGE == housing.AGE.min()]
# Out:
#      CRIM    ZN  INDUS   CHAS    NOX     RM    AGE   DIS    RAD   TAX  \
# 374   0.0  18.1    0.0  0.668  4.138  100.0  1.137  24.0  666.0  20.2
#
#      PTRATIO      B  LSTAT  MEDV
# 374    396.9  37.97   13.8   NaN

# %% [markdown]
# Neighborhood 374 is the neighborhood with the 'newest' houses and the MEDV is 'NaN'.  If there were more attributes I would use a method like the following, but I dont think the format is as clear.

# %%
housing[housing.AGE == housing.AGE.min()].MEDV
# Out:
# 374   NaN
# Name: MEDV, dtype: float64

# %%
charles = housing[housing['CHAS'] != 0]

# %%
notcharles = housing[housing['CHAS'] == 0]

# %%
river = plt.scatter(charles['PTRATIO'], charles['CRIM'], color='red')

# %%
noriver = plt.scatter(notcharles['PTRATIO'], notcharles['CRIM'], color='blue')

# %%
plt.legend((river, noriver), ('Near River', 'Not Near River'))

# %%
plt.ylabel('Crime')

# %%
plt.xlabel('Teacher Pupil Ratio')

# %%
plt.show()

# %% [markdown]
# The above graph shows the relationship between the pupil-teach ratio (x-axis) and the Crime rate, (y-axis).  Neighborhoods bordering the Charles River are shown in Red.  Other neighborhoods are blue.  The data show that crime rates are only higher than zero where Teacher to Pupil Ratios are lower.  If you zoom in you can see more clearly that most neighborhoods have PTRATIO's between 12 and 22, and all neighborhoods outside that range are near the river and have a crime rate of 0.

# %%
zoomin = housing[housing['PTRATIO'] < 30]

# %%
charles = zoomin[zoomin['CHAS'] != 0]

# %%
notcharles = zoomin[zoomin['CHAS'] == 0]

# %%
river = plt.scatter(charles['PTRATIO'], charles['CRIM'], color='red')

# %%
noriver = plt.scatter(notcharles['PTRATIO'], notcharles['CRIM'], color='blue')

# %%
plt.legend((river, noriver), ('Near River', 'Not Near River'))

# %%
plt.ylabel('Crime')

# %%
plt.xlabel('Teacher Pupil Ratio')

# %%
plt.show()

# %%
plt.clf()

# %%
plt.scatter(housing['B'], housing['DIS'])

# %%
plt.title('Black Citizens and Employment Centers')

# %%
plt.xlabel('Measure of Black Citizens')

# %%
plt.ylabel('Distance to an Employment Center')

# %%
plt.show()

# %% [markdown]
# The above graph shows the relationship between concentration of black citizens in a neighborhood and the distance to employment centers.  The data show that most neighborhoods cluster with similar a measure of black citizens between 350 and 400, and a distance to employment centers between 0 and 10.  The major outliers are either far from centers with low black populations (rural areas?) or ones close to emmployment centers with lower than average black populations.

# %%
plt.clf()

# %%
fig, ax = plt.subplots()

# %%
ax2 = ax.twinx()

# %%
nox = housing.plot(ax=ax, kind='scatter', x='MEDV', y='NOX', color='green')

# %%
RE = housing.plot(ax=ax2, kind='scatter', x='MEDV', y='INDUS', color='blue', secondary_y=True)

# %%
ax.set_xlabel('Median Home Value')

# %%
ax.set_ylabel('Nitric Oxides Concentraion pp 10 million (green)')

# %%
ax2.set_ylabel('Proportion Non-Retail Businesses (blue)')

# %%
plt.title('Nitrous and Non-Retail Businesses')

# %%
plt.show()

# %% [markdown]
# The data show that nitric oxides and the proportion of non-retail businesses both have inverse relationships to home prices.  The two measures appear to be closely related.  I would hypothosize that non-retail businesses are more likely to produce nitric oxides, a type of air pollution.

# %%
plt.clf()

# %%
plt.scatter(housing['AGE'], housing['ZN'])

# %%
plt.title('The Age of big Houses')

# %%
plt.xlabel('Proportion built before 1940')

# %%
plt.ylabel('Proportion of Residences bigger than 25,000 sqft')

# %%
plt.show()

# %% [markdown]
# I was interested whether neighborhoods with large houses tended to have more younger houses or older houses.  The data show that there is an inverse relationship between age and size.  Neighborhoods with more large houses tend to have houses that were mostly built since 1940.
